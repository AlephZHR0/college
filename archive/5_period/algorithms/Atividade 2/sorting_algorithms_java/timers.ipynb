# %%
import json

# %%
metricas = {
    "Rodada_0": {
        "Vetor_de_tamanho_10": {
            "BubbleSort": {"Tamanho": 10, "Começou": 1716768182160, "Terminou": 1716768182160},
            "SelectionSort": {"Tamanho": 10, "Começou": 1716768182169, "Terminou": 1716768182169},
            "InsertionSort": {"Tamanho": 10, "Começou": 1716768182169, "Terminou": 1716768182169},
            "MergeSort": {"Tamanho": 10, "Começou": 1716768182170, "Terminou": 1716768182170},
            "QuickSort": {"Tamanho": 10, "Começou": 1716768182170, "Terminou": 1716768182171},
        },
        "Vetor_de_tamanho_100": {
            "BubbleSort": {"Tamanho": 100, "Começou": 1716768182171, "Terminou": 1716768182171},
            "SelectionSort": {"Tamanho": 100, "Começou": 1716768182171, "Terminou": 1716768182171},
            "InsertionSort": {"Tamanho": 100, "Começou": 1716768182171, "Terminou": 1716768182171},
            "MergeSort": {"Tamanho": 100, "Começou": 1716768182171, "Terminou": 1716768182171},
            "QuickSort": {"Tamanho": 100, "Começou": 1716768182171, "Terminou": 1716768182171},
        },
        "Vetor_de_tamanho_1000": {
            "BubbleSort": {"Tamanho": 1000, "Começou": 1716768182172, "Terminou": 1716768182176},
            "SelectionSort": {"Tamanho": 1000, "Começou": 1716768182176, "Terminou": 1716768182178},
            "InsertionSort": {"Tamanho": 1000, "Começou": 1716768182179, "Terminou": 1716768182180},
            "MergeSort": {"Tamanho": 1000, "Começou": 1716768182180, "Terminou": 1716768182181},
            "QuickSort": {"Tamanho": 1000, "Começou": 1716768182181, "Terminou": 1716768182181},
        },
        "Vetor_de_tamanho_10000": {
            "BubbleSort": {"Tamanho": 10000, "Começou": 1716768182182, "Terminou": 1716768182212},
            "SelectionSort": {"Tamanho": 10000, "Começou": 1716768182212, "Terminou": 1716768182229},
            "InsertionSort": {"Tamanho": 10000, "Começou": 1716768182229, "Terminou": 1716768182248},
            "MergeSort": {"Tamanho": 10000, "Começou": 1716768182248, "Terminou": 1716768182249},
            "QuickSort": {"Tamanho": 10000, "Começou": 1716768182250, "Terminou": 1716768182250},
        },
        "Vetor_de_tamanho_100000": {
            "BubbleSort": {"Tamanho": 100000, "Começou": 1716768182252, "Terminou": 1716768191095},
            "SelectionSort": {"Tamanho": 100000, "Começou": 1716768191095, "Terminou": 1716768192899},
            "InsertionSort": {"Tamanho": 100000, "Começou": 1716768192900, "Terminou": 1716768194708},
            "MergeSort": {"Tamanho": 100000, "Começou": 1716768194709, "Terminou": 1716768194720},
            "QuickSort": {"Tamanho": 100000, "Começou": 1716768194720, "Terminou": 1716768194726},
        },
        "Vetor_de_tamanho_1000000": {
            "BubbleSort": {"Tamanho": 1000000, "Começou": 1716768194734, "Terminou": 1716769105840},
            "SelectionSort": {"Tamanho": 1000000, "Começou": 1716769105843, "Terminou": 1716769284967},
            "InsertionSort": {"Tamanho": 1000000, "Começou": 1716769284970, "Terminou": 1716769339710},
            "MergeSort": {"Tamanho": 1000000, "Começou": 1716769339713, "Terminou": 1716769339842},
            "QuickSort": {"Tamanho": 1000000, "Começou": 1716769339845, "Terminou": 1716769339905},
        },
    },


    "Rodada_1": {
        "Vetor_de_tamanho_10": {
            "BubbleSort": {"Tamanho": 10, "Começou": 1716769775523, "Terminou": 1716769775524},
            "SelectionSort": {"Tamanho": 10, "Começou": 1716769775532, "Terminou": 1716769775532},
            "InsertionSort": {"Tamanho": 10, "Começou": 1716769775533, "Terminou": 1716769775533},
            "MergeSort": {"Tamanho": 10, "Começou": 1716769775533, "Terminou": 1716769775533},
            "QuickSort": {"Tamanho": 10, "Começou": 1716769775534, "Terminou": 1716769775534},
        },
        "Vetor_de_tamanho_100": {
            "BubbleSort": {"Tamanho": 100, "Começou": 1716769775534, "Terminou": 1716769775534},
            "SelectionSort": {"Tamanho": 100, "Começou": 1716769775534, "Terminou": 1716769775534},
            "InsertionSort": {"Tamanho": 100, "Começou": 1716769775535, "Terminou": 1716769775535},
            "MergeSort": {"Tamanho": 100, "Começou": 1716769775535, "Terminou": 1716769775535},
            "QuickSort": {"Tamanho": 100, "Começou": 1716769775535, "Terminou": 1716769775535},
        },
        "Vetor_de_tamanho_1000": {
            "BubbleSort": {"Tamanho": 1000, "Começou": 1716769775535, "Terminou": 1716769775538},
            "SelectionSort": {"Tamanho": 1000, "Começou": 1716769775539, "Terminou": 1716769775541},
            "InsertionSort": {"Tamanho": 1000, "Começou": 1716769775541, "Terminou": 1716769775543},
            "MergeSort": {"Tamanho": 1000, "Começou": 1716769775543, "Terminou": 1716769775544},
            "QuickSort": {"Tamanho": 1000, "Começou": 1716769775544, "Terminou": 1716769775544},
        },
        "Vetor_de_tamanho_10000": {
            "BubbleSort": {"Tamanho": 10000, "Começou": 1716769775545, "Terminou": 1716769775575},
            "SelectionSort": {"Tamanho": 10000, "Começou": 1716769775575, "Terminou": 1716769775592},
            "InsertionSort": {"Tamanho": 10000, "Começou": 1716769775592, "Terminou": 1716769775616},
            "MergeSort": {"Tamanho": 10000, "Começou": 1716769775617, "Terminou": 1716769775618},
            "QuickSort": {"Tamanho": 10000, "Começou": 1716769775618, "Terminou": 1716769775619},
        },
        "Vetor_de_tamanho_100000": {
            "BubbleSort": {"Tamanho": 100000, "Começou": 1716769775621, "Terminou": 1716769784448},
            "SelectionSort": {"Tamanho": 100000, "Começou": 1716769784449, "Terminou": 1716769786244},
            "InsertionSort": {"Tamanho": 100000, "Começou": 1716769786245, "Terminou": 1716769788037},
            "MergeSort": {"Tamanho": 100000, "Começou": 1716769788038, "Terminou": 1716769788049},
            "QuickSort": {"Tamanho": 100000, "Começou": 1716769788049, "Terminou": 1716769788055},
        },
        "Vetor_de_tamanho_1000000": {
            "BubbleSort": {"Tamanho": 1000000, "Começou": 1716769788062, "Terminou": 1716770699252},
            "SelectionSort": {"Tamanho": 1000000, "Começou": 1716770699256, "Terminou": 1716770879191},
            "InsertionSort": {"Tamanho": 1000000, "Começou": 1716770879193, "Terminou": 1716770934260},
            "MergeSort": {"Tamanho": 1000000, "Começou": 1716770934262, "Terminou": 1716770934384},
            "QuickSort": {"Tamanho": 1000000, "Começou": 1716770934387, "Terminou": 1716770934458},
        },
    },
    "Rodada_2":{
        "Vetor_de_tamanho_10": {
            "BubbleSort": {"Tamanho": 10, "Começou": 1716776247913, "Terminou": 1716776247914},
            "SelectionSort": {"Tamanho": 10, "Começou": 1716776247921, "Terminou": 1716776247922},
            "InsertionSort": {"Tamanho": 10, "Começou": 1716776247922, "Terminou": 1716776247922},
            "MergeSort": {"Tamanho": 10, "Começou": 1716776247922, "Terminou": 1716776247923},
            "QuickSort": {"Tamanho": 10, "Começou": 1716776247923, "Terminou": 1716776247923},
        },
        "Vetor_de_tamanho_100": {
            "BubbleSort": {"Tamanho": 100, "Começou": 1716776247923, "Terminou": 1716776247923},
            "SelectionSort":{"Tamanho": 100, "Começou": 1716776247923, "Terminou": 1716776247923},
            "InsertionSort":{"Tamanho": 100, "Começou": 1716776247925, "Terminou": 1716776247925},
            "MergeSort": {"Tamanho": 100, "Começou": 1716776247925, "Terminou": 1716776247925},
            "QuickSort": {"Tamanho": 100, "Começou": 1716776247925, "Terminou": 1716776247925},
        },
        "Vetor_de_tamanho_1000": {
            "BubbleSort": {"Tamanho": 1000, "Começou": 1716776247925, "Terminou": 1716776247929},
            "SelectionSort": {"Tamanho": 1000, "Começou": 1716776247929, "Terminou": 1716776247931},
            "InsertionSort": {"Tamanho": 1000, "Começou": 1716776247931, "Terminou": 1716776247933},
            "MergeSort": {"Tamanho": 1000, "Começou": 1716776247933, "Terminou": 1716776247934},
            "QuickSort": {"Tamanho": 1000, "Começou": 1716776247934, "Terminou": 1716776247934},
        },
        "Vetor_de_tamanho_10000": {
            "BubbleSort": {"Tamanho": 10000, "Começou": 1716776247934, "Terminou": 1716776247967},
            "SelectionSort": {"Tamanho": 10000, "Começou": 1716776247968, "Terminou": 1716776247984},
            "InsertionSort": {"Tamanho": 10000, "Começou": 1716776247985, "Terminou": 1716776248007},
            "MergeSort": {"Tamanho": 10000, "Começou": 1716776248007, "Terminou": 1716776248008},
            "QuickSort": {"Tamanho": 10000, "Começou": 1716776248009, "Terminou": 1716776248009},
        },
        "Vetor_de_tamanho_100000": {
            "BubbleSort": {"Tamanho": 100000, "Começou": 1716776248011, "Terminou": 1716776256853},
            "SelectionSort": {"Tamanho": 100000, "Começou": 1716776256854, "Terminou": 1716776258647},
            "InsertionSort": {"Tamanho": 100000, "Começou": 1716776258648, "Terminou": 1716776260461},
            "MergeSort": {"Tamanho": 100000, "Começou": 1716776260461, "Terminou": 1716776260474},
            "QuickSort": {"Tamanho": 100000, "Começou": 1716776260474, "Terminou": 1716776260481},
        },
        "Vetor_de_tamanho_1000000": {
            "BubbleSort": {"Tamanho": 1000000, "Começou": 1716776260489, "Terminou": 1716777171536},
            "SelectionSort": {"Tamanho": 1000000, "Começou": 1716777171539, "Terminou": 1716777352251},
            "InsertionSort": {"Tamanho": 1000000, "Começou": 1716777352253, "Terminou": 1716777407127},
            "MergeSort": {"Tamanho": 1000000, "Começou": 1716777407129, "Terminou": 1716777407286},
            "QuickSort": {"Tamanho": 1000000, "Começou": 1716777407294, "Terminou": 1716777407365},
        },
    }
}

# %%
print(json.dumps(metricas, indent=4))
# Out:
# {
#     "Rodada_0": {
#         "Vetor_de_tamanho_10": {
#             "BubbleSort": {
#                 "Tamanho": 10,
#                 "Come\u00e7ou": 1716768182160,
#                 "Terminou": 1716768182160
#             },
#             "SelectionSort": {
#                 "Tamanho": 10,
#                 "Come\u00e7ou": 1716768182169,
#                 "Terminou": 1716768182169
#             },
#             "InsertionSort": {
#                 "Tamanho": 10,
#                 "Come\u00e7ou": 1716768182169,
#                 "Terminou": 1716768182169
#             },
#             "MergeSort": {
#                 "Tamanho": 10,
#                 "Come\u00e7ou": 1716768182170,
#                 "Terminou": 1716768182170
#             },
#             "QuickSort": {
#                 "Tamanho": 10,
#                 "Come\u00e7ou": 1716768182170,
#                 "Terminou": 1716768182171
#             }
#         },
#         "Vetor_de_tamanho_100": {
# ...

# %%
# Out:
# {'Rodada_0': {'Vetor_de_tamanho_10': {'BubbleSort': {'Tamanho': 10, 'Começou': 1716768182160, 'Terminou': 1716768182160}, 'SelectionSort': {'Tamanho': 10, 'Começou': 1716768182169, 'Terminou': 1716768182169}, 'InsertionSort': {'Tamanho': 10, 'Começou': 1716768182169, 'Terminou': 1716768182169}, 'MergeSort': {'Tamanho': 10, 'Começou': 1716768182170, 'Terminou': 1716768182170}, 'QuickSort': {'Tamanho': 10, 'Começou': 1716768182170, 'Terminou': 1716768182171}}, 'Vetor_de_tamanho_100': {'BubbleSort': {'Tamanho': 100, 'Começou': 1716768182171, 'Terminou': 1716768182171}, 'SelectionSort': {'Tamanho': 100, 'Começou': 1716768182171, 'Terminou': 1716768182171}, 'InsertionSort': {'Tamanho': 100, 'Começou': 1716768182171, 'Terminou': 1716768182171}, 'MergeSort': {'Tamanho': 100, 'Começou': 1716768182171, 'Terminou': 1716768182171}, 'QuickSort': {'Tamanho': 100, 'Começou': 1716768182171, 'Terminou': 1716768182171}}, 'Vetor_de_tamanho_1000': {'BubbleSort': {'Tamanho': 1000, 'Começou': 17167681821
# ...

# %%
# Out:
# ['Rodada 0\nVetor de tamanho 10 gerado.\nBubbleSort - Tamanho: 10Começou: 1716768182160 Terminou: 1716768182160ms\nSelectionSort - Tamanho: 10Começou: 1716768182169 Terminou: 1716768182169ms\nInsertionSort - Tamanho: 10Começou: 1716768182169 Terminou: 1716768182169ms\nMergeSort - Tamanho: 10Começou: 1716768182170 Terminou: 1716768182170ms\nQuickSort - Tamanho: 10Começou: 1716768182170 Terminou: 1716768182171ms\nVetor de tamanho 100 gerado.\nBubbleSort - Tamanho: 100Começou: 1716768182171 Terminou: 1716768182171ms\nSelectionSort - Tamanho: 100Começou: 1716768182171 Terminou: 1716768182171ms\nInsertionSort - Tamanho: 100Começou: 1716768182171 Terminou: 1716768182171ms\nMergeSort - Tamanho: 100Começou: 1716768182171 Terminou: 1716768182171ms\nQuickSort - Tamanho: 100Começou: 1716768182171 Terminou: 1716768182171ms\nVetor de tamanho 1000 gerado.\nBubbleSort - Tamanho: 1000Começou: 1716768182172 Terminou: 1716768182176ms\nSelectionSort - Tamanho: 1000Começou: 1716768182176 Terminou: 17167
# ...
